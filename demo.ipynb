# %%
import pandas as pd
import sqlite3
from typing import List, Dict, Tuple
from pql import PQL

# %%
a = pd.read_csv('./data.csv')
b = pd.read_csv('./data2.csv')

# %%
a.head()
# Out:
#                   date   beef   veal    pork  lamb_and_mutton  broilers  \
# 0  1944-01-01 00:00:00  751.0   85.0  1280.0             89.0       NaN
# 1  1944-02-01 00:00:00  713.0   77.0  1169.0             72.0       NaN
# 2  1944-03-01 00:00:00  741.0   90.0  1128.0             75.0       NaN
# 3  1944-04-01 00:00:00  650.0   89.0   978.0             66.0       NaN
# 4  1944-05-01 00:00:00  681.0  106.0  1029.0             78.0       NaN
#
#    other_chicken  turkey
# 0            NaN     NaN
# 1            NaN     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN

# %%
b.head()
# Out:
#    year   births  rate
# 0  1910  2777000  30.1
# 1  1915  2965000  29.5
# 2  1920  2950000  27.7
# 3  1925  2909000  25.1
# 4  1930  2618000  21.3

# %%
aa = PQL([(pd.read_csv('./data.csv'), 'meat'), (pd.read_csv('data2.csv'), 'birth')])

# %%
aa.q('select * from meat limit 5')
# Out:
#    index                 date   beef   veal    pork  lamb_and_mutton broilers  \
# 0      0  1944-01-01 00:00:00  751.0   85.0  1280.0             89.0     None
# 1      1  1944-02-01 00:00:00  713.0   77.0  1169.0             72.0     None
# 2      2  1944-03-01 00:00:00  741.0   90.0  1128.0             75.0     None
# 3      3  1944-04-01 00:00:00  650.0   89.0   978.0             66.0     None
# 4      4  1944-05-01 00:00:00  681.0  106.0  1029.0             78.0     None
#
#   other_chicken turkey
# 0          None   None
# 1          None   None
# 2          None   None
# 3          None   None
# 4          None   None

# %%
aa.q('select * from birth limit 5')
# Out:
#    index  year   births  rate
# 0      0  1910  2777000  30.1
# 1      1  1915  2965000  29.5
# 2      2  1920  2950000  27.7
# 3      3  1925  2909000  25.1
# 4      4  1930  2618000  21.3
